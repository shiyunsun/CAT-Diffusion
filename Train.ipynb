# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CAT-Diffusion
# Out:
# /content/drive/MyDrive/CAT-Diffusion

# %%
from Diffusion import *
from UNet import *
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision.datasets import DatasetFolder
from PIL import Image
import torchvision.utils as vutils
from utils import *

# %%
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
])
data_path = 'Data'
dataset = ImageFolder(root=data_path, transform=transform)
batch_size = 50
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
train(train_loader, 200)
# Out:
# epoch 1/200
# train: train_noise_loss = 0.0065
# epoch 2/200
# train: train_noise_loss = 0.0064
# epoch 3/200
# train: train_noise_loss = 0.0064
# epoch 4/200
# train: train_noise_loss = 0.0064
# epoch 5/200
# train: train_noise_loss = 0.0060
# epoch 6/200
# train: train_noise_loss = 0.0060
# epoch 7/200
# train: train_noise_loss = 0.0065
# epoch 8/200
# train: train_noise_loss = 0.0061
# epoch 9/200
# train: train_noise_loss = 0.0062
# epoch 10/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1228c14a97c2> in <cell line: 1>()
# ----> 1 train(train_loader, 200)
#
# /content/drive/MyDrive/CAT-Diffusion/utils.py in train(train_loader, epochs)
#      56         epoch = i + 1
#      57         print('epoch {}/{}'.format(epoch, epochs))
# ---> 58         train_noise_loss = train_helper(train_loader, model, optimizer)
#      59         print('train: train_noise_loss = {:.4f}'.format(train_noise_loss))
#      60         torch.save(model, 'save/model.pth')
#
# /content/drive/MyDrive/CAT-Diffusion/utils.py in train_helper(train_loader, model, optimizer)
#      34     i = 0
#      35     for images, conditions in tqdm(train_loader, leave = False, desc = 'training'):
# ---> 36         images = images.to(device)
#      37         noise_loss = model(images)
#      38         train_loss = train_loss + noise_loss.item()
#
# KeyboardInterrupt:
